# %% [markdown]
# <a href="https://colab.research.google.com/github/ab0929/ProjectMaker/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikitlearn

# %% [markdown]
# import pandas as pd
# import matplotlib.pyplot as plt
# ct2 = {'Name' : ['Ab', 'Xx', 'Yy', 'Zz', 'Dd'],
#              'REG No' : [ 1 , 2 , 3 , 4 , 5 ],
#              'Math' : [47, 46, 45, 44, 43],
#              'Semiconductor Physics   ' : [47, 39, 45, 44, 47],
#              'English' : [37, 34, 37, 36, 38],
#              'BEEE' : [47, 44, 47, 46, 48],
#              'FDA' : [ 47 , 44 , 47 , 46 , 48 ]}
# cd=pd.DataFrame(ct2)
# fdapercent=cd['FDA'].sum(axis=0)/2.50
# mthpercent=cd['Math'].sum(axis=0)/2.50
# value=[fdapercent,mthpercent]
# colors=['green','red']
# labels=['Fdapass%','Mathpass%']
# plt.pie(value,colors=colors,labels=labels)
# plt.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np
dx = 0.01
dy = 0.01
x = np.arange(-2.0,2.0,dx)
y = np.arange(-2.0,2.0,dy)
X,Y = np.meshgrid(x,y)
def f(x,y):
    return (1 - y**5 + x**5)*np.exp(-x**2-y**2)
C = plt.contour(X,Y,f(X,Y),8,colors='black')
plt.contourf(X,Y,f(X,Y),8)
plt.clabel(C, inline=1, fontsize=10)
plt.colorbar()

# %%
import matplotlib.pyplot as plt
import numpy as np
N = 8
theta = np.arange(0.,2 * np.pi, 2 * np.pi / N)
radii = np.array([4,7,5,3,1,5,6,7])
plt.axes([0.025, 0.025, 0.95, 0.95], polar=True)
colors = np.array(['lightgreen' , 'darkred' ,  'navy' , 'brown' , 'violet' , 'plum' , 'yellow' , 'darkgreen'])
bars = plt.bar(theta, radii, width=(2*np.pi/N),bottom=0,color=colors)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-2,2,0.1)
Y = np.arange(-2,2,0.1)
X,Y = np.meshgrid(X,Y)
def f(x,y):
  return (1 - y**5 + x**5)*np.exp(-x**2-y**2)
ax.plot_surface(X,Y,f(X,Y), rstride=1, cstride=1,color='green')

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
xs = np.random.randint(30,40,100)
ys = np.random.randint(20,30,100)
zs = np.random.randint(10,20,100)
xs2 = np.random.randint(50,60,100)
ys2 = np.random.randint(30,40,100)
zs2 = np.random.randint(50,70,100)
xs3 = np.random.randint(10,30,100)
ys3 = np.random.randint(40,50,100)
zs3 = np.random.randint(40,50,100)
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(xs,ys,zs,c='g')
ax.scatter(xs2,ys2,zs2,c='k',marker='^')
ax.scatter(xs3,ys3,zs3,c='r',marker='*')
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
# Out:
# Text(0.5, 0, 'Z Label')

# %%
import pandas as pd
data = {'Name' : ['Ab', 'Xx', 'Yy', 'Zz', 'Dd'],
'REGNo' : [ 1 , 2 , 3 , 4 , 5 ],
'Math' : [18, 15, 16, 19, 17],
'Semiconductor Physics ' : [17, 19, 15, 14, 17],
'English' : [17, 14, 17, 16, 18],
'BEEE' : [17, 14, 17, 16, 18],
'FDA' : [ 17 , 14 , 17 , 16 , 18 ]}
ab=pd.DataFrame(data)
ab1 = ab[ab['FDA']<15]
ab1.Name
# Out:
# 1    Xx
# Name: Name, dtype: object

# %%
ab1.REGNo
# Out:
# 1    2
# Name: REGNo, dtype: int64

# %%
ab1.FDA
# Out:
# 1    14
# Name: FDA, dtype: int64

# %%
import numpy as np
bin=int(input())
data =np.array([1,2,3,3,6,4,45,7])
a=pd.cut(data,bins=bin)
a
# Out:
# 4
# [(0.956, 12.0], (0.956, 12.0], (0.956, 12.0], (0.956, 12.0], (0.956, 12.0], (0.956, 12.0], (34.0, 45.0], (0.956, 12.0]]
# Categories (4, interval[float64, right]): [(0.956, 12.0] < (12.0, 23.0] < (23.0, 34.0] <
#                                            (34.0, 45.0]]

# %%
import pandas as pd
ct1 = {'Name' : ['Ab', 'Xx', 'Yy', 'Zz', 'Dd'],
'REGNo' : [ 1 , 2 , 3 , 4 , 5 ],
'Math' : [18, 15, 16, 19, 17],
'Semiconductor Physics ' : [17, 19, 15, 14, 17],
'English' : [17, 14, 17, 16, 18],
'BEEE' : [17, 14, 17, 16, 18],
'FDA' : [ 17 , 14 , 17 , 16 , 18 ]}
ct2 = {'Name' : ['Ab', 'Xx', 'Yy', 'Zz', 'Dd'],
'REGNo' : [ 1 , 2 , 3 , 4 , 5 ],
'Math' : [47, 46, 45, 44, 43],
'Semiconductor Physics ' : [47, 39, 45, 44, 47],
'English' : [37, 34, 37, 36, 38],
'BEEE' : [47, 44, 47, 46, 48],
'FDA' : [ 47 , 44 , 47 , 46 , 48 ]}
ab=pd.DataFrame(ct1)
cd=pd.DataFrame(ct2)
ab1 = pd.merge(ab,cd,on = 'Math')
ab1
# Out:
# Empty DataFrame
# Columns: [Name_x, REGNo_x, Math, Semiconductor Physics _x, English_x, BEEE_x, FDA_x, Name_y, REGNo_y, Semiconductor Physics _y, English_y, BEEE_y, FDA_y]
# Index: []

# %%
from matplotlib import pyplot as plt
x=[1,2,3]
y=[7,10,5]
plt.plot(x,y,color='black')
plt.title("linear  chart")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
import pandas as pd
ct2 = {'Name' : ['Ab', 'Xx', 'Yy', 'Zz', 'Dd'],
'REG No' : [ 1 , 2 , 3 , 4 , 5 ],
'Math' : [47, 46, 45, 44, 43],
'Semiconductor Physics ' : [47, 39, 45, 44, 47],
'English' : [37, 34, 37, 36, 38],
'BEEE' : [47, 44, 47, 46, 48],
'FDA' : [ 47 , 44 , 47 , 46 , 48 ]}
cd=pd.DataFrame(ct2)
fdapercent =(cd['FDA'].sum(axis=0)*100)/250
Mathpercent = (cd['Math'].sum(axis=0)*100)/250
colors=['green','red']
labels=['Fdapass%','FDAfail%']
labels1=['Mathpass%','Mathfail%']
value=[fdapercent,100-fdapercent]
value1=[Mathpercent,100-Mathpercent]
plt.pie(value,colors=colors,labels=labels,explode =(0.1,0),autopct=('%.1f%%'))
plt.legend()

# %%
plt.pie(value1,colors=colors,labels=labels1,explode =(0.05,0 ),autopct=('%.1f%%'))
plt.legend()

# %%
import numpy as np
a=np.array([1,2,3])
a
# Out:
# array([1, 2, 3])
